# %%
import numpy as np

# %%
marks = np.array([45, 78, 32, 90, 55])
idx = np.argsort(marks)
print(idx)
# Out:
# [2 0 4 1 3]

# %%
students = np.array(["Ravi", "Priya", "Arjun", "Sneha", "Karthik"])
marks    = np.array([45,      78,      32,       90,      55])

# %%
students[np.argsort(marks)[::-1]]
# Out:
# array(['Sneha', 'Priya', 'Karthik', 'Ravi', 'Arjun'], dtype='<U7')
