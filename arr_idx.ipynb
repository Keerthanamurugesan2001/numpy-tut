# %% [markdown]
# # Array Indexing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
a = np.arange(1, 6)
a

# %% [markdown]
# Get element form two dimensional array

# %%
a2 = np.array([[1, 2, 3], [4, 5, 6]])
a2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Slicing

# %% [markdown]
# [start: stop: step]

# %%
a = np.arange(1, 6)
a

# %% [markdown]
# Slicing in two dimensional

# %% [markdown]
# [row_start: row_end, column_start:column_end]

# %%
a3 = np.array([[10, 20, 30],
[40, 50, 60],
[70, 80, 90]])
a3

# %% [markdown]
# Execrise:
# Give me only the middle column from all the rows?

# %% [markdown]
# ## Fancy Indexing

# %%
a = np.arange(1, 6)
a

# %% [markdown]
# Execrise: Find the middle data from the array?

# %% [markdown]
# Important consideration:
#
#     Views Vs Copy

# %% [markdown]
# ### Slicing

# %%
a = np.arange(1,6)
a

# %% [markdown]
# ### Fancy Indexing

# %%
a = np.arange(1,6)
a

# %% [markdown]
# ### Mixed Indexing

# %% [markdown]
# slicing + indexing

# %%
a = np.array([[10, 20, 30],
[40, 50, 60],
[70, 80, 90]])
a
